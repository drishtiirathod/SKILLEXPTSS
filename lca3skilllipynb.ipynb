# %% [markdown]
# Step1:Load and combine the dataset of BOT-IOT

# %%
import pandas as pd
df1 = pd.read_csv('/content/UNSW_2018_IoT_Botnet_Full5pc_1.csv')
df2 = pd.read_csv('/content/UNSW_2018_IoT_Botnet_Full5pc_2.csv')
df3 = pd.read_csv('/content/UNSW_2018_IoT_Botnet_Full5pc_3.csv')
df4 = pd.read_csv('/content/UNSW_2018_IoT_Botnet_Full5pc_4.csv')
print("df1 columns:",df1.columns)
print("df2 columns:",df2.columns)
print("df3 columns:",df3.columns)
print("df4 columns:",df4.columns)
# Out:
# <ipython-input-4-b00510dc7652>:2: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('/content/UNSW_2018_IoT_Botnet_Full5pc_1.csv')
# <ipython-input-4-b00510dc7652>:3: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('/content/UNSW_2018_IoT_Botnet_Full5pc_2.csv')
# <ipython-input-4-b00510dc7652>:4: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv('/content/UNSW_2018_IoT_Botnet_Full5pc_3.csv')
# <ipython-input-4-b00510dc7652>:5: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df4 = pd.read_csv('/content/UNSW_2018_IoT_Botnet_Full5pc_4.csv')
# df1 columns: Index(['pkSeqID', 'stime', 'flgs', 'flgs_number', 'proto', 'proto_number',
#        'saddr', 'sport', 'daddr', 'dport', 'pkts', 'bytes', 'state',
# ...

# %%
print(df1.shape)
print(df2.shape)
print(df3.shape)
print(df4.shape)
# Out:
# (1000000, 46)
# (1000000, 46)
# (903591, 42)
# (610181, 46)

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True)
print(df.shape)
df.head()
# Out:
# (3513772, 124)
#    pkSeqID         stime flgs  flgs_number proto  proto_number  \
# 0      1.0  1.528089e+09    e          1.0   tcp           1.0
# 1      2.0  1.528089e+09    e          1.0   arp           2.0
# 2      3.0  1.528089e+09    e          1.0   tcp           1.0
# 3      4.0  1.528089e+09    e          1.0   tcp           1.0
# 4      5.0  1.528089e+09    e          1.0   tcp           1.0
#
#              saddr  sport            daddr dport  ...  1100.2  1100.3  \
# 0  192.168.100.147  49960    192.168.100.7    80  ...     NaN     NaN
# 1    192.168.100.7     -1  192.168.100.147    -1  ...     NaN     NaN
# 2  192.168.100.147  49962    192.168.100.7    80  ...     NaN     NaN
# 3  192.168.100.147  49964    192.168.100.7    80  ...     NaN     NaN
# 4  192.168.100.147  49966    192.168.100.7    80  ...     NaN     NaN
#
#   0.802668  0.802668.1  100.1  0.802711  0.802668.2  1100.4  1100.5  UDP
# 0      NaN         NaN    NaN       NaN         NaN     NaN     NaN  NaN
# ...

# %%
import pandas as pd
df = pd.concat([df1, df2, df3, df4], ignore_index=True)
print("Final concatenated dataset shape:", df.shape)
# Out:
# Final concatenated dataset shape: (3513772, 124)

# %%
display(df.info())
display(df.describe())
display(df.size)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3513772 entries, 0 to 3513771
# Columns: 124 entries, pkSeqID to UDP
# dtypes: float64(101), object(23)
# memory usage: 3.2+ GB
# None

# %% [markdown]
# Step 2:Data preprocessing

# %% [markdown]
# Handling missing values

# %%
# Handle Missing Values
import numpy as np
df.replace(['?', '--', 'na'], np.nan, inplace=True)
df.fillna(method='ffill', inplace=True)

# Remove Duplicates
df.drop_duplicates(inplace=True)

# Remove Outliers using Z-Score
from scipy import stats
z_scores = np.abs(stats.zscore(df.select_dtypes(include=[np.number])))
df = df[(z_scores < 3).all(axis=1)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0dbf4d26defe> in <cell line: 0>()
#       1 # Handle Missing Values
#       2 import numpy as np
# ----> 3 df.replace(['?', '--', 'na'], np.nan, inplace=True)
#       4 df.fillna(method='ffill', inplace=True)
#       5
#
# NameError: name 'df' is not defined
